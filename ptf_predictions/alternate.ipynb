# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt
import theano
import theano.gpuarray
import pygpu
from pygpu import gpuarray
theano.gpuarray.use("cuda"+str(0))
from six.moves import cPickle
import os
import matplotlib.colors as mcolors
from mpl_toolkits.axes_grid1 import make_axes_locatable
import statistics as stats

e={0:'EW',1:'EA',2:'RRab',3:'RRc',4:'RRd',5:'RSCVn',6:'LPV'}
g={0:'AGN',1:'SN', 2:'Fl', 3:'CV', 4:'Bl'}

f=open('n_obj.save','rb')
n_net=cPickle.load(f)
f.close()

f=open('p_obj.save','rb')
p_net=cPickle.load(f)
f.close()

x_p=np.load("../periodic/code/experiments/cnn/X_test.npy")
y_p=np.load("../periodic/code/experiments/cnn/y_test.npy")

x_n=np.load("../code/experiments/cnn/X_test.npy")
y_n=np.load("../code/experiments/cnn/y_test.npy")

pro_p=p_net.predict_proba(x_n)
pro_n=n_net.predict_proba(x_p)

pro_p_max=np.array([np.argmax(pro_p[i]) for i in range(pro_p.shape[0])])
pro_n_max=np.array([np.argmax(pro_n[i]) for i in range(pro_n.shape[0])])

n_p_1=pro_p_max[y_n==1]
n_p_2=pro_p_max[y_n==2]
n_p_3=pro_p_max[y_n==3]
n_p_4=pro_p_max[y_n==4]
n_p_5=pro_p_max[y_n==5]

p_n_1=pro_n_max[y_p==1]
p_n_2=pro_n_max[y_p==2]
p_n_4=pro_n_max[y_p==4]
p_n_5=pro_n_max[y_p==5]
p_n_6=pro_n_max[y_p==6]
p_n_8=pro_n_max[y_p==8]
p_n_13=pro_n_max[y_p==13]

os.mkdir("alternate")

a=plt.hist(p_n_1, bins=[0,1,2,3,4,5])[0]
plt.close()
plt.bar(['AGN','SN','Fl','CV','Bl'],a)
plt.xlabel("Transient Class")
plt.ylabel("Number of Objects")
plt.title("EW")
plt.savefig("alternate/EW.png")
plt.close()

a=plt.hist(p_n_2, bins=[0,1,2,3,4,5])[0]
plt.close()
plt.bar(['AGN','SN','Fl','CV','Bl'],a)
plt.xlabel("Transient Class")
plt.ylabel("Number of Objects")
plt.title("EA")
plt.savefig("alternate/EA.png")
plt.close()

a=plt.hist(p_n_4, bins=[0,1,2,3,4,5])[0]
plt.close()
plt.bar(['AGN','SN','Fl','CV','Bl'],a)
plt.xlabel("Transient Class")
plt.ylabel("Number of Objects")
plt.title("RRab")
plt.savefig("alternate/RRab.png")
plt.close()

a=plt.hist(p_n_5, bins=[0,1,2,3,4,5])[0]
plt.close()
plt.bar(['AGN','SN','Fl','CV','Bl'],a)
plt.xlabel("Transient Class")
plt.ylabel("Number of Objects")
plt.title("RRc")
plt.savefig("alternate/RRc.png")
plt.close()

a=plt.hist(p_n_6, bins=[0,1,2,3,4,5])[0]
plt.close()
plt.bar(['AGN','SN','Fl','CV','Bl'],a)
plt.xlabel("Transient Class")
plt.ylabel("Number of Objects")
plt.title("RRd")
plt.savefig("alternate/RRd.png")
plt.close()

a=plt.hist(p_n_8, bins=[0,1,2,3,4,5])[0]
plt.close()
plt.bar(['AGN','SN','Fl','CV','Bl'],a)
plt.xlabel("Transient Class")
plt.ylabel("Number of Objects")
plt.title("RSCVn")
plt.savefig("alternate/RSCVn.png")
plt.close()

a=plt.hist(p_n_13, bins=[0,1,2,3,4,5])[0]
plt.close()
plt.bar(['AGN','SN','Fl','CV','Bl'],a)
plt.xlabel("Transient Class")
plt.ylabel("Number of Objects")
plt.title("LPV")
plt.savefig("alternate/LPV.png")
plt.close()

a=plt.hist(n_p_1, bins=[0,1,2,3,4,5,6,7])[0]
plt.close()
plt.bar(['EW','EA','RRab','RRc','RRd','RSCVn','LPV'],a)
plt.xlabel("Periodic Class")
plt.ylabel("Number of Objects")
plt.title("AGN")
plt.savefig("alternate/AGN.png")
plt.close()

a=plt.hist(n_p_2, bins=[0,1,2,3,4,5,6,7])[0]
plt.close()
plt.bar(['EW','EA','RRab','RRc','RRd','RSCVn','LPV'],a)
plt.xlabel("Periodic Class")
plt.ylabel("Number of Objects")
plt.title("SN")
plt.savefig("alternate/SN.png")
plt.close()

a=plt.hist(n_p_3, bins=[0,1,2,3,4,5,6,7])[0]
plt.close()
plt.bar(['EW','EA','RRab','RRc','RRd','RSCVn','LPV'],a)
plt.xlabel("Periodic Class")
plt.ylabel("Number of Objects")
plt.title("Fl")
plt.savefig("alternate/Fl.png")
plt.close()

a=plt.hist(n_p_4, bins=[0,1,2,3,4,5,6,7])[0]
plt.close()
plt.bar(['EW','EA','RRab','RRc','RRd','RSCVn','LPV'],a)
plt.xlabel("Periodic Class")
plt.ylabel("Number of Objects")
plt.title("CV")
plt.savefig("alternate/CV.png")
plt.close()

a=plt.hist(n_p_5, bins=[0,1,2,3,4,5,6,7])[0]
plt.close()
plt.bar(['EW','EA','RRab','RRc','RRd','RSCVn','LPV'],a)
plt.xlabel("Periodic Class")
plt.ylabel("Number of Objects")
plt.title("Bl")
plt.savefig("alternate/Bl.png")
plt.close()
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Can not use cuDNN on context None: cannot compile with cuDNN. We got this error:
# b'/tmp/try_flags_v_bz664x.c:4:10: fatal error: cudnn.h: No such file or directory\n #include <cudnn.h>\n          ^~~~~~~~~\ncompilation terminated.\n'
# Mapped name None to device cuda0: Tesla P100-PCIE-12GB (0000:81:00.0)
# /data/mbg/anaconda3/lib/python3.6/site-packages/lasagne/layers/corrmm.py:37: UserWarning: You are using a GPU layer with Theano configured for double precision (floatX=float64). Depending on your Theano version and GPU, this may be slow or unsupported. We recommend to configure Theano for single precision (floatX=float32); see http://lasagne.readthedocs.org/en/latest/user/installation.html#gpu-support.
#   warnings.warn("You are using a GPU layer with Theano configured for "
# ...
