# %% [markdown]
# https://github.com/zzzace2000/FIDO-saliency

# %%
#!pip3 install http://download.pytorch.org/whl/cu80/torch-0.3.0.post4-cp36-cp36m-linux_x86_64.whl
# !pip3 install visdom
# Out:
# ...
#      |████████████████████████████████| 1.4MB 3.5MB/s
# ...
#      |████████████████████████████████| 204kB 41.5MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/ee/87/ce/a5023722374ca73b57fc8d4284ba6f973c01219b3c385a07e0
# ...
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom torchfile
# ...

# %%
import torch
import visdom
torch.__version__
# Out:
# '1.1.0'

# %%
# !git clone https://github.com/zzzace2000/FIDO-saliency.git
# %cd FIDO-saliency/
# Out:
# Cloning into 'FIDO-saliency'...
# remote: Enumerating objects: 211, done.
# remote: Total 211 (delta 0), reused 0 (delta 0), pack-reused 211
# Receiving objects: 100% (211/211), 39.97 MiB | 32.69 MiB/s, done.
# Resolving deltas: 100% (97/97), done.
# /content/FIDO-saliency

# %%
# %cd exp/vbd_imagenet/
# !git clone https://github.com/zzzace2000/generative_inpainting.git
# Out:
# /content/FIDO-saliency/exp/vbd_imagenet
# Cloning into 'generative_inpainting'...
# remote: Enumerating objects: 152, done.
# remote: Total 152 (delta 0), reused 0 (delta 0), pack-reused 152
# Receiving objects: 100% (152/152), 4.39 MiB | 19.65 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
from google.colab import drive
drive.mount('/gdrive')
#%cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
ls
# Out:
# generative_inpainting/  __init__.py         utils_model.py
# imgs/                   train_gen_model.py  vbd_imagenet.py

# %%
# !python -u vbd_imagenet.py --importance-method bbmp_ssr --classifier "/gdrive/My Drive/periodic_tf/code/experiments/cnn/model.h5"  --dropout_param_size 56 56 --epochs 300 --lr 0.05 --reg-coef 5e-3 --gen-model-name CAInpainter --save-dir "/gdrive/My Drive/periodic_tf/xai/FIDO/" --num-imgs 50 --dataset "/gdrive/periodic_tf/data/all/X_2d.npy" --data-dir "/gdrive/periodic_tf/data/all/"
# Out:
# Traceback (most recent call last):
#   File "vbd_imagenet.py", line 13, in <module>
#     from arch.sensitivity.BDNet import OppositeGernarativeL1BDNet, GernarativeL1BDNet
#   File "/content/FIDO-saliency/arch/sensitivity/BDNet.py", line 212, in <module>
#     class GernarativeBDNet(BDNet):
#   File "/content/FIDO-saliency/arch/sensitivity/BDNet.py", line 213, in GernarativeBDNet
#     def __init__(self, dropout_param_size, trained_classifier, generative_model=MeanInpainter(),
# NameError: name 'MeanInpainter' is not defined

# %%
# %cd vbd_imagenet/
# Out:
# /content/FIDO-saliency/exp/vbd_imagenet
