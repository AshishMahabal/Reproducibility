# %% [markdown]
# http://netdissect.csail.mit.edu/

# %%
# !git clone https://github.com/CSAILVision/NetDissect-Lite
# %cd NetDissect-Lite
# Out:
# Cloning into 'NetDissect-Lite'...
# remote: Enumerating objects: 147, done.
# remote: Total 147 (delta 0), reused 0 (delta 0), pack-reused 147
# Receiving objects: 100% (147/147), 64.60 KiB | 1.29 MiB/s, done.
# Resolving deltas: 100% (81/81), done.
# /content/NetDissect-Lite

# %%
# !script/dlbroden.sh
# !script/dlzoo_example.sh
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !pip3 install scipy==1.1.0
# Out:
# ...
#      |████████████████████████████████| 31.2MB 1.3MB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.3.0
#     Uninstalling scipy-1.3.0:
#       Successfully uninstalled scipy-1.3.0
# ...

# %%
# %cd NetDissect-Lite
# Out:
# /content/NetDissect-Lite

# %%
# !python main.py
# Out:
# /content/NetDissect-Lite/loader/data_loader.py:150: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[list(np.indices(arr.shape)) + [arr]] = 1
# file missing, loading from scratch
# extracting feature from batch 1 / 495
# /content/NetDissect-Lite/feature_operation.py:66: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   input_var = V(input,volatile=True)
# extracting feature from batch 2 / 495
# extracting feature from batch 3 / 495
# extracting feature from batch 4 / 495
# extracting feature from batch 5 / 495
# extracting feature from batch 6 / 495
# extracting feature from batch 7 / 495
# extracting feature from batch 8 / 495
# extracting feature from batch 9 / 495
# ...

# %%
# !result/pytorch_resnet18_places365/html/layer4.html
# Out:
# /bin/bash: result/pytorch_resnet18_places365/html/layer4.html: Permission denied
