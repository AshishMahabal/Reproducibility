# %%
# !git clone https://github.com/affinelayer/pix2pix-tensorflow.git
# %cd pix2pix-tensorflow
# Out:
# Cloning into 'pix2pix-tensorflow'...
# remote: Enumerating objects: 261, done.
# remote: Total 261 (delta 0), reused 0 (delta 0), pack-reused 261
# Receiving objects: 100% (261/261), 13.33 MiB | 29.74 MiB/s, done.
# Resolving deltas: 100% (103/103), done.
# /content/pix2pix-tensorflow

# %%
from google.colab import drive
drive.mount('/gdrive')
#%cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# !python pix2pix.py \
--mode train \
--output_dir "/gdrive/My Drive/periodic_tf/xai/pix2pix/shap/EW/training_output/" \
--max_epochs 200 \
--input_dir "/gdrive/My Drive/periodic_tf/xai/trainingdata/shap/EW/" \
--which_direction AtoB \
--checkpoint "/gdrive/My Drive/periodic_tf/xai/pix2pix/shap/EW/training_output/"
# Out:
# WARNING:tensorflow:From pix2pix.py:540: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# aspect_ratio = 1.0
# batch_size = 1
# beta1 = 0.5
# checkpoint = /gdrive/My Drive/periodic_tf/xai/pix2pix/shap/EW/training_output/
# display_freq = 0
# flip = True
# gan_weight = 1.0
# input_dir = /gdrive/My Drive/periodic_tf/xai/trainingdata/shap/EW/
# l1_weight = 100.0
# lab_colorization = False
# lr = 0.0002
# max_epochs = 200
# max_steps = None
# mode = train
# ndf = 64
# ngf = 64
# output_dir = /gdrive/My Drive/periodic_tf/xai/pix2pix/shap/EW/training_output/
# output_filetype = png
# progress_freq = 50
# save_freq = 5000
# scale_size = 286
# seed = 875830763
# separable_conv = False
# summary_freq = 100
# trace_freq = 0
# which_direction = AtoB
# WARNING:tensorflow:From pix2pix.py:258: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# !python pix2pix.py \
  --mode test \
  --output_dir "/gdrive/My Drive/periodic_tf/xai/pix2pix/shap/EW/test_output/" \
  --input_dir "/gdrive/My Drive/periodic_tf/xai/testdata/shap/EW/" \
  --checkpoint "/gdrive/My Drive/periodic_tf/xai/pix2pix/shap/EW/training_output/"
# Out:
# WARNING:tensorflow:From pix2pix.py:540: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# loaded lab_colorization = False
# loaded ndf = 64
# loaded ngf = 64
# loaded which_direction = AtoB
# aspect_ratio = 1.0
# batch_size = 1
# beta1 = 0.5
# checkpoint = /gdrive/My Drive/periodic_tf/xai/pix2pix/shap/EW/training_output/
# display_freq = 0
# flip = False
# gan_weight = 1.0
# input_dir = /gdrive/My Drive/periodic_tf/xai/testdata/shap/EW/
# l1_weight = 100.0
# lab_colorization = False
# lr = 0.0002
# max_epochs = None
# max_steps = None
# mode = test
# ndf = 64
# ngf = 64
# output_dir = /gdrive/My Drive/periodic_tf/xai/pix2pix/shap/EW/test_output/
# output_filetype = png
# progress_freq = 50
# save_freq = 5000
# scale_size = 256
# seed = 698166263
# separable_conv = False
# summary_freq = 100
# trace_freq = 0
# which_direction = AtoB
# ...
